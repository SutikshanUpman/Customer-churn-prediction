# %%
import tensorflow as tf
import pandas as pd
from tensorflow import keras
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("WA_Fn-UseC_-Telco-Customer-Churn.csv")

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
# 3         Yes          No              No        One year               No
# 4          No          No              No  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges  TotalCharges Churn
# 0           Electronic check          29.85         29.85    No
# 1               Mailed check          56.95        1889.5    No
# 2               Mailed check          53.85        108.15   Yes
# 3  Bank transfer (automatic)          42.30       1840.75    No
# 4           Electronic check          70.70        151.65   Yes
#
# [5 rows x 21 columns]

# %%
df.drop('customerID',axis='columns',inplace=True)
df.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
df.TotalCharges.values #strings ... needs to convert
# Out:
# array(['29.85', '1889.5', '108.15', ..., '346.45', '306.6', '6844.5'],
#       dtype=object)

# %%
# Convert to numeric, turning spaces into NaN
pd.to_numeric(df['TotalCharges'], errors='coerce').isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7038    False
# 7039    False
# 7040    False
# 7041    False
# 7042    False
# Name: TotalCharges, Length: 7043, dtype: bool

# %%
df[pd.to_numeric(df['TotalCharges'], errors='coerce').isnull()].shape
# Out:
# (11, 20)

# %%
df.shape
# Out:
# (7043, 20)

# %%
df[pd.to_numeric(df['TotalCharges'], errors='coerce').isnull()]
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 488   Female              0     Yes        Yes       0           No
# 753     Male              0      No        Yes       0          Yes
# 936   Female              0     Yes        Yes       0          Yes
# 1082    Male              0     Yes        Yes       0          Yes
# 1340  Female              0     Yes        Yes       0           No
# 3331    Male              0     Yes        Yes       0          Yes
# 3826    Male              0     Yes        Yes       0          Yes
# 4380  Female              0     Yes        Yes       0          Yes
# 5218    Male              0     Yes        Yes       0          Yes
# 6670  Female              0     Yes        Yes       0          Yes
# 6754    Male              0      No        Yes       0          Yes
#
#          MultipleLines InternetService       OnlineSecurity  \
# 488   No phone service             DSL                  Yes
# 753                 No              No  No internet service
# 936                 No             DSL                  Yes
# 1082               Yes              No  No internet service
# 1340  No phone service             DSL                  Yes
# 3331                No              No  No internet service
# 3826               Yes              No  No internet service
# 4380                No              No  No internet service
# 5218                No              No  No internet service
# 6670               Yes             DSL                   No
# 6754               Yes             DSL                  Yes
#
#              OnlineBackup     DeviceProtection          TechSupport  \
# 488                    No                  Yes                  Yes
# 753   No internet service  No internet service  No internet service
# 936                   Yes                  Yes                   No
# 1082  No internet service  No internet service  No internet service
# 1340                  Yes                  Yes                  Yes
# 3331  No internet service  No internet service  No internet service
# 3826  No internet service  No internet service  No internet service
# 4380  No internet service  No internet service  No internet service
# 5218  No internet service  No internet service  No internet service
# 6670                  Yes                  Yes                  Yes
# 6754                  Yes                   No                  Yes
#
#               StreamingTV      StreamingMovies  Contract PaperlessBilling  \
# 488                   Yes                   No  Two year              Yes
# 753   No internet service  No internet service  Two year               No
# 936                   Yes                  Yes  Two year               No
# 1082  No internet service  No internet service  Two year               No
# 1340                  Yes                   No  Two year               No
# 3331  No internet service  No internet service  Two year               No
# 3826  No internet service  No internet service  Two year               No
# 4380  No internet service  No internet service  Two year               No
# 5218  No internet service  No internet service  One year              Yes
# 6670                  Yes                   No  Two year               No
# 6754                   No                   No  Two year              Yes
#
#                   PaymentMethod  MonthlyCharges TotalCharges Churn
# 488   Bank transfer (automatic)           52.55                 No
# 753                Mailed check           20.25                 No
# 936                Mailed check           80.85                 No
# 1082               Mailed check           25.75                 No
# 1340    Credit card (automatic)           56.05                 No
# 3331               Mailed check           19.85                 No
# 3826               Mailed check           25.35                 No
# 4380               Mailed check           20.00                 No
# 5218               Mailed check           19.70                 No
# 6670               Mailed check           73.35                 No
# 6754  Bank transfer (automatic)           61.90                 No

# %%
df.iloc[488]['TotalCharges']
# Out:
# ' '

# %%
#droping 11 out of 7043 is okay
df1 = df[df['TotalCharges']!=" "]
df1.shape
# Out:
# (7032, 20)

# %%
df1.TotalCharges = pd.to_numeric(df1.TotalCharges)
# Out:
# C:\Users\upman\AppData\Local\Temp\ipykernel_17200\973151263.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.TotalCharges = pd.to_numeric(df1.TotalCharges)

# %%
df1.TotalCharges.dtypes
# Out:
# dtype('float64')

# %%
df1
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0     Female              0     Yes         No       1           No
# 1       Male              0      No         No      34          Yes
# 2       Male              0      No         No       2          Yes
# 3       Male              0      No         No      45           No
# 4     Female              0      No         No       2          Yes
# ...      ...            ...     ...        ...     ...          ...
# 7038    Male              0     Yes        Yes      24          Yes
# 7039  Female              0     Yes        Yes      72          Yes
# 7040  Female              0     Yes        Yes      11           No
# 7041    Male              1     Yes         No       4          Yes
# 7042    Male              0      No         No      66          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0     No phone service             DSL             No          Yes
# 1                   No             DSL            Yes           No
# 2                   No             DSL            Yes          Yes
# 3     No phone service             DSL            Yes           No
# 4                   No     Fiber optic             No           No
# ...                ...             ...            ...          ...
# 7038               Yes             DSL            Yes           No
# 7039               Yes     Fiber optic             No          Yes
# 7040  No phone service             DSL            Yes           No
# 7041               Yes     Fiber optic             No           No
# 7042                No     Fiber optic            Yes           No
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0                  No          No          No              No  Month-to-month
# 1                 Yes          No          No              No        One year
# 2                  No          No          No              No  Month-to-month
# 3                 Yes         Yes          No              No        One year
# 4                  No          No          No              No  Month-to-month
# ...               ...         ...         ...             ...             ...
# 7038              Yes         Yes         Yes             Yes        One year
# 7039              Yes          No         Yes             Yes        One year
# 7040               No          No          No              No  Month-to-month
# 7041               No          No          No              No  Month-to-month
# 7042              Yes         Yes         Yes             Yes        Two year
#
#      PaperlessBilling              PaymentMethod  MonthlyCharges  \
# 0                 Yes           Electronic check           29.85
# 1                  No               Mailed check           56.95
# 2                 Yes               Mailed check           53.85
# 3                  No  Bank transfer (automatic)           42.30
# 4                 Yes           Electronic check           70.70
# ...               ...                        ...             ...
# 7038              Yes               Mailed check           84.80
# 7039              Yes    Credit card (automatic)          103.20
# 7040              Yes           Electronic check           29.60
# 7041              Yes               Mailed check           74.40
# 7042              Yes  Bank transfer (automatic)          105.65
#
#       TotalCharges Churn
# 0            29.85    No
# 1          1889.50    No
# 2           108.15   Yes
# 3          1840.75    No
# 4           151.65   Yes
# ...            ...   ...
# 7038       1990.50    No
# 7039       7362.90    No
# 7040        346.45    No
# 7041        306.60   Yes
# 7042       6844.50    No
#
# [7032 rows x 20 columns]

# %%
#lets plot tenure, monthly_charges, senior_citizen, gender vs churntenure_churn_yes = df1[df1.Churn=='Yes'].tenure
#label encoding bhi lagegi 
tenure_churn_yes = df1[df1.Churn=='Yes'].tenure
tenure_churn_no = df1[df1.Churn=='No'].tenure

plt.xlabel("Tenure")
plt.ylabel("Customers Count")
plt.grid(axis='y', linestyle='--')
plt.hist([tenure_churn_yes,tenure_churn_no],color=['lightgreen','orange'],label=['churn_yes','churn_no'])
plt.legend()

# %%
mc_churn_yes = df1[df1.Churn=='Yes'].MonthlyCharges
mc_churn_no = df1[df1.Churn=='No'].MonthlyCharges

plt.xlabel("MonthlyCharges")
plt.grid(axis='y', linestyle='--')
plt.ylabel("Customers Count")
plt.hist([mc_churn_yes,mc_churn_no],color=['lightgreen','orange'],label=['churn_yes','churn_no'])
plt.legend()

# %%
gender_churn = df1.groupby(['gender', 'Churn']).size()
print(gender_churn)
# Out:
# gender  Churn
# Female  No       2544
#         Yes       939
# Male    No       2619
#         Yes       930
# dtype: int64

# %%
senior_churn  = df1.groupby(['SeniorCitizen', 'Churn']).size()
print(senior_churn )
# Out:
# SeniorCitizen  Churn
# 0              No       4497
#                Yes      1393
# 1              No        666
#                Yes       476
# dtype: int64

# %%
senior_churn = senior_churn.unstack()
senior_churn.plot(kind='bar', stacked=True, color=['skyblue', 'salmon'])
plt.ylabel('Number of Customers')
plt.xticks([0, 1],rotation=0)
plt.grid(axis='y', linestyle='--')
plt.show()

# %%
for column in df:
    if df[column].dtype == 'object' :
        print(f'{column} : {df[column].unique()}')
# Out:
# gender : ['Female' 'Male']
# Partner : ['Yes' 'No']
# Dependents : ['No' 'Yes']
# PhoneService : ['No' 'Yes']
# MultipleLines : ['No phone service' 'No' 'Yes']
# InternetService : ['DSL' 'Fiber optic' 'No']
# OnlineSecurity : ['No' 'Yes' 'No internet service']
# OnlineBackup : ['Yes' 'No' 'No internet service']
# DeviceProtection : ['No' 'Yes' 'No internet service']
# TechSupport : ['No' 'Yes' 'No internet service']
# StreamingTV : ['No' 'Yes' 'No internet service']
# StreamingMovies : ['No' 'Yes' 'No internet service']
# Contract : ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling : ['Yes' 'No']
# PaymentMethod : ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# TotalCharges : ['29.85' '1889.5' '108.15' ... '346.45' '306.6' '6844.5']
# Churn : ['No' 'Yes']

# %%
df1.replace('No internet service','No',inplace=True)
df1.replace('No phone service','No',inplace=True)
# Out:
# C:\Users\upman\AppData\Local\Temp\ipykernel_17200\2045096646.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.replace('No internet service','No',inplace=True)
# C:\Users\upman\AppData\Local\Temp\ipykernel_17200\2045096646.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.replace('No phone service','No',inplace=True)

# %%
yes_no_columns = ['Partner','Dependents','PhoneService','MultipleLines','OnlineSecurity','OnlineBackup',
                  'DeviceProtection','TechSupport','StreamingTV','StreamingMovies','PaperlessBilling','Churn']
for col in yes_no_columns:
    df1[col].replace({'Yes': 1,'No': 0},inplace=True)
# Out:
# C:\Users\upman\AppData\Local\Temp\ipykernel_17200\1648037665.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1[col].replace({'Yes': 1,'No': 0},inplace=True)
# C:\Users\upman\AppData\Local\Temp\ipykernel_17200\1648037665.py:4: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df1[col].replace({'Yes': 1,'No': 0},inplace=True)
# C:\Users\upman\AppData\Local\Temp\ipykernel_17200\1648037665.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[col].replace({'Yes': 1,'No': 0},inplace=True)

# %%
df1['gender'].replace({'Female':1,'Male':0},inplace=True)
# Out:
# C:\Users\upman\AppData\Local\Temp\ipykernel_17200\698335744.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1['gender'].replace({'Female':1,'Male':0},inplace=True)
# C:\Users\upman\AppData\Local\Temp\ipykernel_17200\698335744.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df1['gender'].replace({'Female':1,'Male':0},inplace=True)
# C:\Users\upman\AppData\Local\Temp\ipykernel_17200\698335744.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['gender'].replace({'Female':1,'Male':0},inplace=True)

# %%
for col in df1:
    print(f'{col}: {df1[col].unique()}')
# Out:
# gender: [1 0]
# SeniorCitizen: [0 1]
# Partner: [1 0]
# Dependents: [0 1]
# tenure: [ 1 34  2 45  8 22 10 28 62 13 16 58 49 25 69 52 71 21 12 30 47 72 17 27
#   5 46 11 70 63 43 15 60 18 66  9  3 31 50 64 56  7 42 35 48 29 65 38 68
#  32 55 37 36 41  6  4 33 67 23 57 61 14 20 53 40 59 24 44 19 54 51 26 39]
# PhoneService: [0 1]
# MultipleLines: [0 1]
# InternetService: ['DSL' 'Fiber optic' 'No']
# OnlineSecurity: [0 1]
# OnlineBackup: [1 0]
# DeviceProtection: [0 1]
# TechSupport: [0 1]
# StreamingTV: [0 1]
# StreamingMovies: [0 1]
# Contract: ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling: [1 0]
# PaymentMethod: ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# MonthlyCharges: [29.85 56.95 53.85 ... 63.1  44.2  78.7 ]
# TotalCharges: [  29.85 1889.5   108.15 ...  346.45  306.6  6844.5 ]
# Churn: [0 1]

# %%
df2 = pd.get_dummies(data=df1, columns=['InternetService','Contract','PaymentMethod'])
df2.sample(5)
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 1428       0              0        0           0       1             1
# 4017       1              0        0           0      28             1
# 4702       0              1        0           0      54             0
# 4568       0              0        0           0      26             1
# 6565       0              0        1           0      61             1
#
#       MultipleLines  OnlineSecurity  OnlineBackup  DeviceProtection  ...  \
# 1428              1               0             0                 0  ...
# 4017              1               1             0                 1  ...
# 4702              0               0             1                 1  ...
# 4568              0               0             1                 1  ...
# 6565              1               1             1                 0  ...
#
#       InternetService_DSL  InternetService_Fiber optic  InternetService_No  \
# 1428                 True                        False               False
# 4017                 True                        False               False
# 4702                 True                        False               False
# 4568                False                         True               False
# 6565                False                         True               False
#
#       Contract_Month-to-month  Contract_One year  Contract_Two year  \
# 1428                     True              False              False
# 4017                    False               True              False
# 4702                    False               True              False
# 4568                    False               True              False
# 6565                     True              False              False
#
#       PaymentMethod_Bank transfer (automatic)  \
# 1428                                    False
# 4017                                    False
# 4702                                    False
# 4568                                    False
# 6565                                    False
#
#       PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 1428                                  False                            True
# 4017                                  False                           False
# 4702                                  False                            True
# 4568                                  False                            True
# 6565                                  False                            True
#
#       PaymentMethod_Mailed check
# 1428                       False
# 4017                        True
# 4702                       False
# 4568                       False
# 6565                       False
#
# [5 rows x 27 columns]

# %%
df2.dtypes
# Out:
# gender                                       int64
# SeniorCitizen                                int64
# Partner                                      int64
# Dependents                                   int64
# tenure                                       int64
# PhoneService                                 int64
# MultipleLines                                int64
# OnlineSecurity                               int64
# OnlineBackup                                 int64
# DeviceProtection                             int64
# TechSupport                                  int64
# StreamingTV                                  int64
# StreamingMovies                              int64
# PaperlessBilling                             int64
# MonthlyCharges                             float64
# TotalCharges                               float64
# Churn                                        int64
# InternetService_DSL                           bool
# InternetService_Fiber optic                   bool
# InternetService_No                            bool
# Contract_Month-to-month                       bool
# Contract_One year                             bool
# Contract_Two year                             bool
# PaymentMethod_Bank transfer (automatic)       bool
# PaymentMethod_Credit card (automatic)         bool
# PaymentMethod_Electronic check                bool
# PaymentMethod_Mailed check                    bool
# dtype: object

# %%
cols_to_scale = ['tenure','MonthlyCharges','TotalCharges']

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df2[cols_to_scale] = scaler.fit_transform(df2[cols_to_scale])

# %%
X = df2.drop('Churn',axis='columns')
y = df2['Churn']

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=5)

# %%
X_train.shape
# Out:
# (5625, 26)

# %%
import numpy as np

X_train = np.array(X_train, dtype=np.float32)
y_train = np.array(y_train, dtype=np.float32)
X_test = np.array(X_test, dtype=np.float32)
y_test = np.array(y_test, dtype=np.float32)

# %%
import tensorflow as tf
from tensorflow import keras


model = keras.Sequential([
    keras.layers.Dense(26, input_shape=(26,), activation='relu'),
    keras.layers.Dense(15, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

model.fit(X_train, y_train, epochs=100)
# Out:
# Epoch 1/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.5622 - accuracy: 0.6914
# Epoch 2/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.4337 - accuracy: 0.7968
# Epoch 3/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.4205 - accuracy: 0.8030
# Epoch 4/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.4154 - accuracy: 0.8041
# Epoch 5/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.4128 - accuracy: 0.8039
# Epoch 6/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.4105 - accuracy: 0.8066
# Epoch 7/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.4089 - accuracy: 0.8082
# Epoch 8/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.4074 - accuracy: 0.8098
# Epoch 9/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.4059 - accuracy: 0.8094
# Epoch 10/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.4051 - accuracy: 0.8084
# Epoch 11/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.4048 - accuracy: 0.8094
# Epoch 12/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.4033 - accuracy: 0.8110
# Epoch 13/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.4029 - accuracy: 0.8112
# Epoch 14/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.4016 - accuracy: 0.8112
# Epoch 15/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.4002 - accuracy: 0.8085
# Epoch 16/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.4002 - accuracy: 0.8144
# Epoch 17/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3986 - accuracy: 0.8128
# Epoch 18/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3978 - accuracy: 0.8144
# Epoch 19/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3975 - accuracy: 0.8139
# Epoch 20/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3966 - accuracy: 0.8146
# Epoch 21/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3962 - accuracy: 0.8119
# Epoch 22/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3958 - accuracy: 0.8142
# Epoch 23/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3938 - accuracy: 0.8124
# Epoch 24/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3939 - accuracy: 0.8156
# Epoch 25/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3932 - accuracy: 0.8153
# Epoch 26/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3929 - accuracy: 0.8165
# Epoch 27/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3916 - accuracy: 0.8151
# Epoch 28/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3919 - accuracy: 0.8174
# Epoch 29/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3902 - accuracy: 0.8194
# Epoch 30/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3892 - accuracy: 0.8171
# Epoch 31/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3889 - accuracy: 0.8201
# Epoch 32/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3881 - accuracy: 0.8210
# Epoch 33/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3873 - accuracy: 0.8196
# Epoch 34/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3871 - accuracy: 0.8204
# Epoch 35/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3885 - accuracy: 0.8196
# Epoch 36/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3857 - accuracy: 0.8203
# Epoch 37/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3850 - accuracy: 0.8224
# Epoch 38/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3843 - accuracy: 0.8229
# Epoch 39/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3841 - accuracy: 0.8224
# Epoch 40/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3841 - accuracy: 0.8228
# Epoch 41/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3824 - accuracy: 0.8233
# Epoch 42/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3830 - accuracy: 0.8183
# Epoch 43/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3821 - accuracy: 0.8228
# Epoch 44/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3805 - accuracy: 0.8251
# Epoch 45/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3804 - accuracy: 0.8244
# Epoch 46/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3805 - accuracy: 0.8231
# Epoch 47/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3796 - accuracy: 0.8238
# Epoch 48/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3801 - accuracy: 0.8228
# Epoch 49/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3777 - accuracy: 0.8270
# Epoch 50/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3772 - accuracy: 0.8258
# Epoch 51/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3774 - accuracy: 0.8270
# Epoch 52/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3764 - accuracy: 0.8286
# Epoch 53/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3756 - accuracy: 0.8258
# Epoch 54/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3762 - accuracy: 0.8270
# Epoch 55/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3751 - accuracy: 0.8258
# Epoch 56/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3749 - accuracy: 0.8281
# Epoch 57/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3735 - accuracy: 0.8276
# Epoch 58/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3725 - accuracy: 0.8270
# Epoch 59/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3730 - accuracy: 0.8318
# Epoch 60/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3720 - accuracy: 0.8267
# Epoch 61/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3708 - accuracy: 0.8268
# Epoch 62/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3721 - accuracy: 0.8267
# Epoch 63/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3694 - accuracy: 0.8324
# Epoch 64/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3703 - accuracy: 0.8279
# Epoch 65/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3693 - accuracy: 0.8297
# Epoch 66/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3700 - accuracy: 0.8318
# Epoch 67/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3691 - accuracy: 0.8316
# Epoch 68/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3681 - accuracy: 0.8295
# Epoch 69/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3676 - accuracy: 0.8318
# Epoch 70/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3672 - accuracy: 0.8315
# Epoch 71/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3659 - accuracy: 0.8332
# Epoch 72/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3663 - accuracy: 0.8341
# Epoch 73/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3648 - accuracy: 0.8315
# Epoch 74/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3644 - accuracy: 0.8329
# Epoch 75/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3653 - accuracy: 0.8306
# Epoch 76/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3627 - accuracy: 0.8320
# Epoch 77/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3631 - accuracy: 0.8336
# Epoch 78/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3628 - accuracy: 0.8348
# Epoch 79/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3627 - accuracy: 0.8347
# Epoch 80/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3620 - accuracy: 0.8329
# Epoch 81/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.3611 - accuracy: 0.8361
# Epoch 82/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3610 - accuracy: 0.8331
# Epoch 83/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3604 - accuracy: 0.8345
# Epoch 84/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3604 - accuracy: 0.8352
# Epoch 85/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3595 - accuracy: 0.8352
# Epoch 86/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3597 - accuracy: 0.8352
# Epoch 87/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3585 - accuracy: 0.8366
# Epoch 88/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3583 - accuracy: 0.8361
# Epoch 89/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3584 - accuracy: 0.8372
# Epoch 90/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3572 - accuracy: 0.8359
# Epoch 91/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3567 - accuracy: 0.8372
# Epoch 92/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3553 - accuracy: 0.8400
# Epoch 93/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3561 - accuracy: 0.8368
# Epoch 94/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3553 - accuracy: 0.8366
# Epoch 95/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3549 - accuracy: 0.8375
# Epoch 96/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3548 - accuracy: 0.8384
# Epoch 97/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3541 - accuracy: 0.8405
# Epoch 98/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3554 - accuracy: 0.8389
# Epoch 99/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3532 - accuracy: 0.8368
# Epoch 100/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3528 - accuracy: 0.8393

# %%
model.evaluate(X_test, y_test)
# Out:
# 44/44 [==============================] - 0s 2ms/step - loss: 0.4699 - accuracy: 0.7768
# [0.46990281343460083, 0.7768301367759705]

# %%
yp = model.predict(X_test)
# Out:
# 44/44 [==============================] - 0s 1ms/step

# %%
y_pred = []
for element in yp:
    if element > 0.5:
        y_pred.append(1)
    else:
        y_pred.append(0)

# %%
y_pred[:10]
# Out:
# [0, 1, 0, 1, 1, 1, 0, 0, 0, 0]

# %%
from sklearn.metrics import confusion_matrix , classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.82      0.88      0.85       999
#          1.0       0.64      0.53      0.58       408
#
#     accuracy                           0.78      1407
#    macro avg       0.73      0.70      0.71      1407
# weighted avg       0.77      0.78      0.77      1407

# %%
import seaborn as sn
cm = tf.math.confusion_matrix(labels=y_test,predictions=y_pred)

plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')

# %%
#classification report and analyze precision, recall and f1-score
